# %% [markdown]
# 1. 本公号内的文章,一般使用 Jupyter Notebook 进行编辑, 使用 Github 进行存储.
# 1. 在本公众号内已发布的文章, 若无重大变更将不会在在公众号内二次发布.
# 1. 关于修改后的版本, 可通过 [Github](https://github.com/y2sinx/Simon-Simple) 或 [NBViewer](https://nbviewer.jupyter.org/) 查看.
#
# 1. MarkDown(或Jupyter Notebook)转公众号图文素材的过程
#     * `.jpynb -> .md ->  MarkDown Nice(https://mdnice.com/) ->  图文素材`
#     * 因为微信公众平台暂时不能插入外链,所以素材中的图片可能需要重新插入.
# 1. 本公众号目前暂无特殊目的,并愿意接收任意类型的文章投稿,其他事项请联系`y2sinx@126.com`
